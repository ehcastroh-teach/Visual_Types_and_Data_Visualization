# %% [markdown]
# # INTRODUCTION TO DATA TYPES AND VISUALIZATION PRINCIPLES
#
# Apply the core ideas from the lesson to the Palmer Penguins dataset. You will explain visualization purposes, construct figures using both Matplotlib APIs, and style statistical charts in Seaborn. Each section targets one Learning Goal from the paired lesson.
#
# ***Summary***
# 1. [Why Visualize? Purposes and Historical Context](#why-visualize)
# 2. [Matplotlib Architecture and API Choice](#matplotlib-architecture)
# 3. [Chart Types in Matplotlib](#chart-types)
# 4. [Statistical Visualization with Seaborn](#seaborn-stats)
# 5. [Generalization: Visualizing Wine Quality Data](#generalization)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_wine

# Load dataset for Sections 1-4
# seaborn built-in: Palmer Penguins (Anderson 2014 / Horst et al. 2020)
# docs: https://seaborn.pydata.org/generated/seaborn.load_dataset.html
penguins = sns.load_dataset("penguins").dropna()
penguins.head()

# %% [markdown]
# ***
# <a id='why-visualize'></a>
# ## 1. Why Visualize? Purposes and Historical Context
#
# Visualization is not one thing - different chart types serve different cognitive purposes. This section asks you to connect the taxonomy from the lesson to real decisions.

# %% [markdown]
# **Q1 a) You are given the penguins dataset. A colleague asks: "Which species tend to have the longest flippers?" Name the visualization purpose this question serves (from the four covered in the lesson) and justify your choice in one sentence. Store your answer in `q1a_purpose`.**
#
# *Hint:* Review the four purposes taxonomy introduced in Part 1 of the lesson.

# %%
### YOUR CODE HERE ###
q1a_purpose = ...  # one of: 'record', 'analyze', 'communicate', 'plan' (or the exact lesson terms)

#print(q1a_purpose)

# %% [markdown]
# *ANSWER HERE*

# %% [markdown]
# **Q1 b) Florence Nightingale's 1858 polar area diagram is a canonical example of visualization enabling a decision in a high-stakes domain. Identify (1) what decision it enabled, (2) which of the four visualization purposes it served, and (3) why a simple table of death counts would have been less persuasive for that audience. Store your written answer in `q1b_answer`.**
#
# *Hint:* Nightingale's diagram is documented at the Nightingale Museum and in Edward Tufte's *The Visual Display of Quantitative Information*.

# %%
### YOUR CODE HERE ###
q1b_answer = """
Decision enabled:
Purpose served:
Why a table would be less persuasive:
"""

# %% [markdown]
# **Q1 c) Create a simple bar chart using `plt.bar()` (state-based API) that shows the mean flipper length for each penguin species. Label the x-axis "Species", label the y-axis "Mean Flipper Length (mm)", and add a title. Store the figure as `q1c_fig`.**
#
# <!-- TODO: generate expected output image by running this cell and saving to assets/q1c_expected.png -->
#
# *Hint:* Use [`pd.DataFrame.groupby`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html) to compute per-species means before plotting.

# %%
### YOUR CODE HERE ###
species_means = ...  # compute mean flipper_length_mm by species

q1c_fig = plt.figure(figsize=(6, 4))
# plt.bar(...)
# plt.xlabel(...)
# plt.ylabel(...)
# plt.title(...)
plt.tight_layout()
plt.show()

# %% [markdown]
# ***
# <a id='matplotlib-architecture'></a>
# ## 2. Matplotlib Architecture and API Choice
#
# Matplotlib exposes two APIs. Understanding which to use - and why - is the difference between code that is easy to extend and code that fights you when requirements change.

# %% [markdown]
# **Q2 a) Using the object-oriented Matplotlib API only (no `plt.plot()` or `plt.bar()` calls), create a figure with two subplots side by side. Left subplot: scatter plot of `bill_length_mm` vs `flipper_length_mm` colored by `species`. Right subplot: box plot of `body_mass_g` grouped by `species`. Store the figure as `q2a_fig` and the two axes as `q2a_ax1` and `q2a_ax2`.**
#
# <!-- TODO: generate expected output image by running this cell and saving to assets/q2a_expected.png -->
#
# *Hint:* Use [`plt.subplots`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html) to create the figure and axes objects together. Color by species using a loop over `penguins.groupby('species')`.

# %%
# TODO: verify ax.boxplot parameter names against current matplotlib docs

### YOUR CODE HERE ###
q2a_fig, (q2a_ax1, q2a_ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Left: scatter by species
for species, group in penguins.groupby('species'):
    q2a_ax1.scatter(...)

q2a_ax1.set_xlabel(...)
q2a_ax1.set_ylabel(...)
q2a_ax1.set_title(...)
q2a_ax1.legend()

# Right: box plot by species
species_list = [group['body_mass_g'].values for _, group in penguins.groupby('species')]
q2a_ax2.boxplot(...)
q2a_ax2.set_xticklabels(penguins['species'].unique())
q2a_ax2.set_xlabel(...)
q2a_ax2.set_ylabel(...)
q2a_ax2.set_title(...)

q2a_fig.tight_layout()
plt.show()

# %% [markdown]
# **Q2 b) In one to two sentences each, explain: (1) what the `Figure` object represents in Matplotlib's hierarchy, (2) what the `Axes` object represents, and (3) why you would choose the object-oriented API over the state-based `plt.*` API when creating a multi-panel figure.**

# %%
### YOUR CODE HERE ###
q2b_answer = """
Figure:
Axes:
Why OO API for multi-panel figures:
"""

# %% [markdown]
# ***
# <a id='chart-types'></a>
# ## 3. Chart Types in Matplotlib
#
# Choosing the right chart type is inseparable from understanding what question you are answering. This section asks you to build four chart families on the penguins data using both APIs.

# %% [markdown]
# **Q3 a) Using the state-based API (`plt.*`), plot a histogram of `flipper_length_mm` with 20 bins. Add a vertical dashed line at the mean value. Label axes and add a title. Store the figure as `q3a_fig`.**
#
# <!-- TODO: generate expected output image by running this cell and saving to assets/q3a_expected.png -->
#
# *Hint:* [`plt.hist`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html), [`plt.axvline`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.axvline.html)

# %%
### YOUR CODE HERE ###
q3a_fig = plt.figure(figsize=(7, 4))
# plt.hist(...)
# plt.axvline(x=penguins['flipper_length_mm'].mean(), ...)
# plt.xlabel(...)
# plt.ylabel(...)
# plt.title(...)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Q3 b) Using the object-oriented API, create a 2x2 grid of subplots on one figure. Each subplot shows a different chart type for a different penguin measurement: (top-left) line chart of mean bill length by island, (top-right) scatter of bill depth vs bill length, (bottom-left) box plot of body mass by sex, (bottom-right) histogram of flipper length. Store the figure as `q3b_fig`.**
#
# <!-- TODO: generate expected output image by running this cell and saving to assets/q3b_expected.png -->
#
# *Hint:* Use `plt.subplots(2, 2, figsize=(12, 9))`. For the line chart, use `groupby('island').mean()` then `ax.plot()` over the index.

# %%
### YOUR CODE HERE ###
q3b_fig, axes = plt.subplots(2, 2, figsize=(12, 9))

# Top-left: line chart of mean bill_length_mm by island
island_means = ...
axes[0, 0].plot(...)
axes[0, 0].set_title(...)

# Top-right: scatter of bill_depth_mm vs bill_length_mm
axes[0, 1].scatter(...)
axes[0, 1].set_title(...)

# Bottom-left: box plot of body_mass_g by sex
sex_groups = [group['body_mass_g'].values for _, group in penguins.groupby('sex')]
axes[1, 0].boxplot(...)
axes[1, 0].set_title(...)

# Bottom-right: histogram of flipper_length_mm
axes[1, 1].hist(...)
axes[1, 1].set_title(...)

q3b_fig.tight_layout()
plt.show()

# %% [markdown]
# **Q3 c) In two sentences, explain why the state-based API is convenient for quick single-plot scripts but becomes a liability when you need to update a specific subplot in a multi-panel figure.**

# %%
### YOUR CODE HERE ###
q3c_answer = """
Convenience for single plots:
Liability for multi-panel figures:
"""

# %% [markdown]
# ***
# <a id='seaborn-stats'></a>
# ## 4. Statistical Visualization with Seaborn
#
# Seaborn's design center is statistical insight: it makes it easy to reveal distributions, relationships, and group comparisons without writing layout boilerplate.

# %% [markdown]
# **Q4 a) Apply the `"darkgrid"` Seaborn theme. Then create a pairplot of the numeric columns in `penguins`, with points colored by `species`. Store the result as `q4a_grid`.**
#
# <!-- TODO: generate expected output image by running this cell and saving to assets/q4a_expected.png -->
#
# *Hint:* [`sns.set_style`](https://seaborn.pydata.org/generated/seaborn.set_style.html), [`sns.pairplot`](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
# TODO: verify sns.set_style parameter name against current seaborn docs

### YOUR CODE HERE ###
sns.set_style(...)
q4a_grid = sns.pairplot(...)
plt.show()

# %% [markdown]
# **Q4 b) Create a FacetGrid that shows a KDE plot of `flipper_length_mm` for each `species` in separate columns. Use the `"whitegrid"` style and the `"muted"` color palette. Store the grid as `q4b_grid`. In one sentence below, explain what the FacetGrid reveals that a single overlapping KDE plot would obscure.**
#
# <!-- TODO: generate expected output image by running this cell and saving to assets/q4b_expected.png -->
#
# *Hint:* [`sns.FacetGrid`](https://seaborn.pydata.org/generated/seaborn.FacetGrid.html), [`FacetGrid.map`](https://seaborn.pydata.org/generated/seaborn.FacetGrid.map.html)

# %%
# TODO: verify sns.FacetGrid col parameter and map syntax against current seaborn docs

### YOUR CODE HERE ###
sns.set_style(...)
sns.set_palette(...)
q4b_grid = sns.FacetGrid(penguins, col=...)
q4b_grid.map(sns.kdeplot, ...)
plt.show()

# %% [markdown]
# *ANSWER HERE* (what the FacetGrid reveals vs. a single overlapping KDE)

# %% [markdown]
# **Q4 c) Create a single figure that contains: (1) a Seaborn violin plot of `body_mass_g` by `species`, and (2) overlaid individual data points using `sns.stripplot` on the same axes. Set the palette to `"Set2"` and suppress the legend on the strip plot. Store the figure as `q4c_fig` and the axes as `q4c_ax`.**
#
# <!-- TODO: generate expected output image by running this cell and saving to assets/q4c_expected.png -->
#
# *Hint:* [`sns.violinplot`](https://seaborn.pydata.org/generated/seaborn.violinplot.html), [`sns.stripplot`](https://seaborn.pydata.org/generated/seaborn.stripplot.html). Pass `ax=q4c_ax` to each call to target the same axes.

# %%
# TODO: verify violinplot and stripplot parameter names against current seaborn docs

### YOUR CODE HERE ###
q4c_fig, q4c_ax = plt.subplots(figsize=(8, 5))

sns.violinplot(data=penguins, x=..., y=..., palette=..., ax=q4c_ax)
sns.stripplot(data=penguins, x=..., y=..., color='black', alpha=0.4, legend=False, ax=q4c_ax)

q4c_ax.set_title(...)
q4c_fig.tight_layout()
plt.show()

# %% [markdown]
# ***
# <a id='generalization'></a>
# ## 5. Generalization: Visualizing Wine Quality Data
#
# Apply the same visualization skills to the UCI Wine dataset, a multi-class classification dataset with 13 numeric features and three wine cultivar classes. The goal is to confirm that you can transfer what you built for penguins to a domain with more features and different shape.

# %%
# Load wine dataset (UCI Wine Recognition, sklearn built-in)
# Source: https://scikit-learn.org/stable/datasets/toy_dataset.html#wine-recognition-dataset
wine_data = load_wine()
wine_df = pd.DataFrame(wine_data.data, columns=wine_data.feature_names)
wine_df['cultivar'] = [wine_data.target_names[t] for t in wine_data.target]
wine_df.head()

# %% [markdown]
# **Q5 a) Using the object-oriented Matplotlib API, create a histogram of the `alcohol` column with 15 bins. Color-code by cultivar (three separate overlapping histograms, one per cultivar, with `alpha=0.5`). Add a legend, axis labels, and a title. Store the figure as `q5a_fig`.**
#
# <!-- TODO: generate expected output image by running this cell and saving to assets/q5a_expected.png -->
#
# *Hint:* Loop over `wine_df.groupby('cultivar')` and call `ax.hist(group['alcohol'], ...)` for each cultivar.

# %%
### YOUR CODE HERE ###
q5a_fig, ax = plt.subplots(figsize=(8, 5))

for cultivar, group in wine_df.groupby('cultivar'):
    ax.hist(...)

ax.set_xlabel(...)
ax.set_ylabel(...)
ax.set_title(...)
ax.legend()
q5a_fig.tight_layout()
plt.show()

# %% [markdown]
# **Q5 b) Using Seaborn, create a FacetGrid that shows a scatter of `alcohol` vs `flavanoids` for each cultivar in a separate column. Apply the `"ticks"` style. Store the grid as `q5b_grid`.**
#
# <!-- TODO: generate expected output image by running this cell and saving to assets/q5b_expected.png -->
#
# *Hint:* Use `sns.FacetGrid(wine_df, col='cultivar').map(sns.scatterplot, 'alcohol', 'flavanoids')`.

# %%
# TODO: verify FacetGrid.map syntax for scatterplot against current seaborn docs

### YOUR CODE HERE ###
sns.set_style(...)
q5b_grid = sns.FacetGrid(...)
q5b_grid.map(...)
plt.show()

# %% [markdown]
# **Q5 c) In two to three sentences, describe one pattern the wine visualizations revealed that would not be visible in a summary statistics table (means, standard deviations). Connect your observation to one of the four visualization purposes from Section 1.**

# %%
### YOUR CODE HERE ###
q5c_answer = """
Pattern observed:
Why invisible in a summary table:
Visualization purpose this demonstrates:
"""
