# %% [markdown]
# <hr style="border: 6px solid#003262;" />
#
# # BREAKOUT 2: Recreate and Improve a Plot
#
# Given a cluttered chart image, recreate it faithfully and then produce an improved version that applies Tufte's principles.
#
# **Skills practiced:** Synthesizing visualization principles with library code; deliberate chart redesign.
#
# **Prerequisite:** Complete `visualization_intro_01_visualization_principles_matplotlib_seaborn.ipynb` and `visualization_intro_02_one_chart_several_libraries.ipynb`.

# %% [markdown]
# ### Problem
#
# <hr style="border: 1px solid#003262;" />
#
# The image `data/story_images/2_Better.png` shows a visualization that can be improved.
#
# 1. **Describe** what is wrong with the original chart. Identify at least two violations of Tufte's principles.
# 2. **Create** a dataset that could produce the data shown in the original chart.
# 3. **Build** an improved version of the chart using your preferred Python visualization library. Apply the principles you identified.

# %%
# Start here - create your dataset and plot
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

### YOUR CODE HERE ###
# Step 1: describe the violations (as comments)
# Violation 1:
# Violation 2:

# Step 2: create the dataset
# data = ...

# Step 3: plot the improved version
# fig, ax = plt.subplots(...)

# %% [markdown]
# <hr style="border: 6px solid#003262;" />
