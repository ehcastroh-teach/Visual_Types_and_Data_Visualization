# %% [markdown]
# <hr style="border: 6px solid#003262;" />
#
# # BREAKOUT 3: Visualization Critique and Redesign
#
# Apply the good / bad / better framework to a real-world chart. Redesign it using Plotly for interactivity.
#
# **Skills practiced:** Systematic visualization critique; interactive chart construction with Plotly.
#
# **Prerequisite:** Complete `visualization_intro_02_one_chart_several_libraries.ipynb` and `visualization_intro_04_plotly_dash_dashboards.ipynb`.

# %% [markdown]
# ### The Good / Bad / Better Framework
#
# <hr style="border: 1px solid#003262;" />
#
# ### Breakout problem
#
#
# <hr style="border: 1px solid#0B0B0B;" />
#
# #### Recall...
#
# <table align="center" style="width:70%; font-size:22px; font-family:FreeMono; font-weight: 100; font-stretch:ultra-condensed; line-height: 1.2; color:#2A2C2B">
#   <tr>
#     <th><strong>GOOD</strong></th>
#     <th><strong>BAD</strong></th>
#     <th><strong>BETTER</strong></th>
#   </tr>
#   <tr>
#       <th style="font-size:16px; font-family:FreeMono; font-weight: 100; font-stretch:ultra-condensed; line-height: 1.2; color:#2A2C2B; vertical-align:top">
#           <div align="center" style="vertical-align:top">
#             <img src= "/data/story_images/1_Good.png" align="Center" width="90%" vertical-align="top">
#           </div>
#       </th>
#       <th style="font-size:16px; font-family:FreeMono; font-weight: 100; font-stretch:ultra-condensed; line-height: 1.2; color:#2A2C2B; vertical-align:top">
#           <div align="center">
#             <img src= "/data/story_images/3_Bad.png" align="Center" width="100%" vertical-align="top">
#           </div>
#       </th>
#       <th style="font-size:16px; font-family:FreeMono; font-weight: 100; font-stretch:ultra-condensed; line-height: 1.2; color:#2A2C2B; vertical-align:top">
#           <div align="center" style="vertical-align:top">
#             <img src= "/data/story_images/2_Better.png" align="Center" width="100%" vertical-align="top">
#           </div>
#       </th>
#   </tr>
# </table>
# <br>
# 1) Use your prefered visualization language and plot the hand-drawned, improved, plot you created in the "Good; Bad --> Better" exercise.
#
# <hr style="border: 1px solid#0B0B0B;" />

# %% [markdown]
# ### Problem
#
# 1. Find a publicly available chart online that you consider "bad" - paste the URL or download and save it to `breakouts/S3/`.
# 2. Describe what makes it bad (at least two specific issues).
# 3. Describe what a "better" version would look like.
# 4. Build the "better" version in Plotly using synthetic or publicly available data.

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

### YOUR CODE HERE ###
# Step 1: paste URL of the bad chart here (as a comment):
# URL:

# Step 2: describe what is bad
# Issue 1:
# Issue 2:

# Step 3: describe the better version
# Better version:

# Step 4: build it in Plotly
# fig = go.Figure()
# fig.add_trace(...)
# fig.update_layout(...)
# fig.show()

# %% [markdown]
# <hr style="border: 6px solid#003262;" />
