# %% [markdown]
# <hr style="border: 6px solid#003262;" />
#
# # BREAKOUT 1: Plotting with Matplotlib
#
# Reproduce a multi-line stock chart from three data files using pandas and matplotlib.
#
# **Dataset:** `google_data.txt`, `yahoo_data.txt`, `ny_temps.txt` in `breakouts/S1/breakout1-data/`
#
# **Skills practiced:** Loading tab-separated data with pandas, overlaying multiple line plots on one axes, setting axis labels, legends, and titles using the object-oriented Matplotlib API.
#
# **Prerequisite:** Complete `visualization_intro_01_visualization_principles_matplotlib_seaborn.ipynb` Part 2.

# %% [markdown]
# ### Problem
#
# Using `Python`, `NumPy`, `pandas`, and `matplotlib`, reproduce the plot shown in `breakout1-data/stocks.png`.
#
# Requirements:
# - Load all three data files using `pd.read_csv` (tab-separated: `sep='	'`)
# - Plot Google and Yahoo stock prices on a shared axes (left y-axis)
# - Plot NY temperatures on a secondary y-axis (right)
# - Add axis labels, a legend, and a title

# %%
# use magickeys to ensure that the following files are in the breakout1-data directory
# google_data.txt  ny_temps.txt     stocks.png       yahoo_data.txt
# %ls ./breakout1-data

# %% [markdown]
# ### Breakout problem
#
# <hr style="border: 1px solid#0B0B0B;" />
#
# Use your knowledge with `Python, NumPy, pandas and matplotlib` to reproduce the plot below:
#
# <div align="center">
#     <img src= "/breakout-S1/answer.png" align="center" width="50%">
# </div>
# <hr style="border: 1px solid#0B0B0B;" />

# %%
# start by loading data and packages
import pandas as pd
import numpy as np
from io import StringIO
import matplotlib.pyplot as plt
google_data = pd.read_csv(pd.read_csv("breakouts/S1/breakout1-data/google_data.txt",sep="\t") # Note data seperator (\t) splits data by tab, or as a table
yahoo_data = pd.read_csv(pd.read_csv("breakouts/S1/breakout1-data/yahoo_data.txt",sep="\t")
ny_temps = pd.read_csv("breakout-S1/data/ny_temps.txt",sep='\t')

# %% [markdown]
# <hr style="border: 6px solid#003262;" />
