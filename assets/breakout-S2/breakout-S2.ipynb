# %% [markdown]
# <hr style="border: 4px solid#0B0B0B;" />
#
# # Breakout 2 - Plotting
#
# **Author list:** Elias Casto Hernandez
#
# **License Agreement:** Feel free to do whatever you want with this code

# %% [markdown]
# ### Breakout problem
#
# <hr style="border: 1px solid#0B0B0B;" />
# <div align="center">
#     <img src= "/assets/data/story_images/improve_the_plot.png" align="center" height="100%">
#
#     #SWDchallenge -- September 2018
# </div>
#
# <br>
#
# <br>
#
# 1) Create a collection of data sets that represent the data you need to illustrate the above
#
# 2) Using the data sets you created, build a plot using your prefered package that displays your improved version of the plot above -- from the hand-drawing exercise.
#
# <hr style="border: 1px solid#0B0B0B;" />

# %%
### Start here
